# %%
# %sql
use catalog acc_dev;
use schema sudhakar;

# %%
# %sql
CREATE TABLE employees (id INT, name STRING, dept STRING);

# %%
# %sql
INSERT INTO EMPLOYEES VALUES (1,'Surya','CSE');

# %%
# %sql
DESC EXTENDED EMPLOYEES;

# %%
# %sql
DESC HISTORY employees;

# %%
# %sql
DESC DETAIL EMPLOYEES;

# %%
# %sql
insert into acc_dev.naval.emp values ('007','Sudhakar','Hyderabad')

# %%
# %sql
select * from acc_dev.naval.emp where id=7

# %%
# %sql
delete from employees

# %%
# %sql
select * from employees

# %%
# %sql
restore employees version as of 2

# %%
# %sql
select * from employees

# %%
df=spark.sql("restore employees version as of 2")

# %%
df.display()
