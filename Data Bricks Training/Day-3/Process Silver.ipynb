# %%
# %run "/Workspace/Users/pallerlasudhakarreddy26@gmail.com/Data Bricks Training/Day-3/includes"

# %%
# reader
df=spark.table(f"{catalog}.{schema}.sales")

#transform
df1=df.dropDuplicates().dropna().drop("ingestion_date","path")

#write
df1.write.mode("overwrite").saveAsTable(f"{catalog}.sudhakar_silver.sales_cleaned")
