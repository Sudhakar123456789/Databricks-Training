# %% [markdown]
# ##Databricks notebook

# %%
# %sql
select 1

# %%
# %sql
CREATE SCHEMA acc_dev.Sudhakar

# %%
# %sql
USE CATALOG acc_dev;
USE SCHEMA Sudhakar;

# %%
# %sql
create table acc_dev.sudhakar.demo(id int primary key)

# %% [markdown]
# ![](/Volumes/acc_dev/naval/raw/object-model.png)

# %%
print("Hello")
